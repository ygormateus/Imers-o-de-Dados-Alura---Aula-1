# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.info() 
dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# ...

# %%
#Selecionar apenas os imoveis da Vila Mariana
sum((dados['Bairro']=='Vila Mariana')) #quantidade de casas no bairro Vila Mariana
tem_imovel = (dados['Bairro']=='Vila Mariana') 
imovel_vila_mariana = dados[tem_imovel]
imovel_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
mais_populoso = (dados['Bairro'].value_counts()) #value_counts organiza os valores em ordem decrescente por nivel de incidencia
mais_populoso.head(5).plot.pie() #Sempre se atentar a sintaxe dos comandos

# %% [markdown]
# 1° Desafio - Realizar a média da metragem para cada um dos bairros. (Proposto pelo Paulo)
#
# ---

# %%
#Media de metragem dos bairros
metragem_bairro = (dados.groupby('Bairro').mean()['Metragem'].sort_values())
metragem_bairro.head(10).plot.barh()

# %% [markdown]
# 2° Desafio - Duas formas de selecionar os dados por bairro (consultar os
# métodos na documentação do Pandas).
#
# ---

# %%
dados['Bairro'][4587]
tem_imovel_jardim = dados['Bairro'] == 'Jardim Viana'
dados[tem_imovel_jardim].head(5)
# Out:
#                      Rua        Bairro     Cidade  Metragem  Quartos  \
# 365                  NaN  Jardim Viana  São Paulo       273        3
# 1034  Rua Luiz Galhanone  Jardim Viana  São Paulo       300        4
# 1038  Rua Luiz Galhanone  Jardim Viana  São Paulo       780        4
# 1069  Rua Luiz Galhanone  Jardim Viana  São Paulo       305        4
# 1075  Rua Luiz Galhanone  Jardim Viana  São Paulo       785        4
#
#       Banheiros  Vagas         Valor
# 365           4      3  R$ 1.600.000
# 1034          4      3  R$ 2.597.000
# 1038          4      6  R$ 5.000.000
# 1069          4      3  R$ 2.597.000
# 1075          4      6  R$ 5.000.000

# %% [markdown]
# **3°** Desafio - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, assim como tentar colocar alguma conclusão.
#
#
# ---

# %%
# Bairros com maior quantidade de imoveis disponivel
maior_bairro = dados['Bairro'].value_counts().head(10).plot.barh()

# %%
dados.hist(figsize=(10,6), layout=(2,3), bins=20)
print()

# %% [markdown]
# **4°** Desafio - Pegar outras estatísticas dos dados (como média, mediana, min, max)

# %%
dados.describe()
# Out:
#             Metragem     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000
# mean      442.300659      3.879097      4.097222
# std      7515.379389      1.988467      2.824014
# min        10.000000      1.000000      1.000000
# 25%       173.000000      2.000000      2.000000
# 50%       290.000000      4.000000      4.000000
# 75%       460.250000      5.000000      5.000000
# max    750000.000000     40.000000     50.000000

# %% [markdown]
# **5°** - Descobrir quais são os bairros que não tem nome de rua

# %%
rua_semnome = dados['Rua'].isnull()
sum(rua_semnome)
dados['Bairro'][rua_semnome].to_frame()
# Out:
#                                 Bairro
# 3                       Jardim Morumbi
# 11                    Jardim Luzitânia
# 31                      Parque da Lapa
# 56    Chácara Santo Antônio (Zona Sul)
# 57                      Jardim Guedala
# ...                                ...
# 9963                 Jardim Petrópolis
# 9989              Parque Alves de Lima
# 9991                      Vila Formosa
# 9995                     Jardim Leonor
# 9999                 Jardim Petrópolis
#
# [3434 rows x 1 columns]
